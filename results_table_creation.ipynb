# %% [markdown]
# ### file for extraction and transformation of fact weather table

# %% [markdown]
# extraction of tables from https://github.com/toUpperCase78/formula1-datasets/tree/master?tab=GPL-3.0-1-ov-file#readme

# %%
import pandas as pd

# %%
results_2020 = pd.read_csv("https://github.com/toUpperCase78/formula1-datasets/blob/master/formula1_2020season_calendar.csv?raw=true")
results_2021 = pd.read_csv("https://github.com/toUpperCase78/formula1-datasets/blob/master/formula1_2021season_calendar.csv?raw=true")
results_2022 = pd.read_csv("https://github.com/toUpperCase78/formula1-datasets/blob/master/Formula1_2022season_calendar.csv?raw=true")
results_2023 = pd.read_csv("https://github.com/toUpperCase78/formula1-datasets/blob/master/Formula1_2023season_calendar.csv?raw=true")
results_2024 = pd.read_csv("https://github.com/toUpperCase78/formula1-datasets/blob/master/Formula1_2024season_calendar.csv?raw=true")

# %%
print(results_2020.columns == results_2021.columns)
print(results_2021.columns == results_2022.columns)
print(results_2022.columns == results_2023.columns)
print(results_2023.columns == results_2024.columns)
# Out:
# [ True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True]
# [ True False False False False False  True  True  True  True  True  True
#   True  True  True]
# [ True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True]
# [ True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True]

# %% [markdown]
# something is wrong so let's check one by one

# %%
print(results_2020.columns)
print(results_2021.columns)
print(results_2022.columns)
print(results_2023.columns)
print(results_2024.columns)
# Out:
# Index(['Round', 'Country', 'City', 'Circuit Name', 'GP Name', 'Race Date',
#        'First GP', 'Number of Laps', 'Circuit Length(km)', 'Race Distance(km)',
#        'Lap Record', 'Record Owner', 'Record Year', 'Turns', 'DRS Zones'],
#       dtype='object')
# Index(['Round', 'Country', 'City', 'Circuit Name', 'GP Name', 'Race Date',
#        'First GP', 'Number of Laps', 'Circuit Length(km)', 'Race Distance(km)',
#        'Lap Record', 'Record Owner', 'Record Year', 'Turns', 'DRS Zones'],
#       dtype='object')
# Index(['Round', 'Race Date', 'GP Name', 'Country', 'City', 'Circuit Name',
#        'First GP', 'Number of Laps', 'Circuit Length(km)', 'Race Distance(km)',
#        'Lap Record', 'Record Owner', 'Record Year', 'Turns', 'DRS Zones'],
#       dtype='object')
# Index(['Round', 'Race Date', 'GP Name', 'Country', 'City', 'Circuit Name',
#        'First GP', 'Number of Laps', 'Circuit Length(km)', 'Race Distance(km)',
# ...

# %%
results_2022 = results_2022[['Round', 'Country', 'City', 'Circuit Name', 'GP Name', 'Race Date',
       'First GP', 'Number of Laps', 'Circuit Length(km)', 'Race Distance(km)',
       'Lap Record', 'Record Owner', 'Record Year', 'Turns', 'DRS Zones']]

# %%
print(results_2021.columns)
print(results_2022.columns)
# Out:
# Index(['Round', 'Country', 'City', 'Circuit Name', 'GP Name', 'Race Date',
#        'First GP', 'Number of Laps', 'Circuit Length(km)', 'Race Distance(km)',
#        'Lap Record', 'Record Owner', 'Record Year', 'Turns', 'DRS Zones'],
#       dtype='object')
# Index(['Round', 'Country', 'City', 'Circuit Name', 'GP Name', 'Race Date',
#        'First GP', 'Number of Laps', 'Circuit Length(km)', 'Race Distance(km)',
#        'Lap Record', 'Record Owner', 'Record Year', 'Turns', 'DRS Zones'],
#       dtype='object')

# %%
results_2022.head(15)
# Out:
#     Round        Country               City                    Circuit Name  \
# 0       1        Bahrain             Sakhir   Bahrain International Circuit
# 1       2   Saudi Arabia             Jeddah         Jeddah Corniche Circuit
# 2       3      Australia          Melbourne             Albert Park Circuit
# 3       4          Italy              Imola   Autodromo Enzo e Dino Ferrari
# 4       5  United States              Miami   Miami International Autodrome
# 5       6          Spain          Catalunya  Circuit de Barcelona-Catalunya
# 6       7         Monaco        Monte Carlo               Circuit de Monaco
# 7       8     Azerbaijan               Baku               Baku City Circuit
# 8       9         Canada           Montréal       Circuit Gilles-Villeneuve
# 9      10  Great Britain        Silverstone             Silverstone Circuit
# 10     11        Austria          Spielberg                   Red Bull Ring
# ...

# %%
results_2021.head()
# Out:
#    Round   Country         City                        Circuit Name  \
# 0      1   Bahrain       Sakhir       Bahrain International Circuit
# 1      2     Italy        Imola       Autodromo Enzo e Dino Ferrari
# 2      3  Portugal     Portimao  Autodromo Internacional do Algarve
# 3      4     Spain    Catalunya      Circuit de Barcelona-Catalunya
# 4      5    Monaco  Monte Carlo                   Circuit de Monaco
#
#           GP Name    Race Date  First GP  Number of Laps  Circuit Length(km)  \
# 0         Bahrain  28 Mar 2021      2004              57               5.412
# 1  Emilia Romagna  18 Apr 2021      1980              63               4.909
# 2        Portugal  02 May 2021      2020              66               4.653
# 3           Spain  09 May 2021      1991              66               4.675
# 4          Monaco  23 May 2021      1950              78               3.337
#
#    Race Distance(km) Lap Record      Record Owner  Record Year  Turns  \
# ...

# %% [markdown]
# the order is correct but will still need to normalize date formatting

# %%
results_2023 = results_2023[['Round', 'Country', 'City', 'Circuit Name', 'GP Name', 'Race Date',
       'First GP', 'Number of Laps', 'Circuit Length(km)', 'Race Distance(km)',
       'Lap Record', 'Record Owner', 'Record Year', 'Turns', 'DRS Zones']]

results_2024 = results_2024[['Round', 'Country', 'City', 'Circuit Name', 'GP Name', 'Race Date',
       'First GP', 'Number of Laps', 'Circuit Length(km)', 'Race Distance(km)',
       'Lap Record', 'Record Owner', 'Record Year', 'Turns', 'DRS Zones']]

# %%
results_2023.head(10)
# Out:
#    Round        Country       City                    Circuit Name  \
# 0      1        Bahrain     Sakhir   Bahrain International Circuit
# 1      2   Saudi Arabia     Jeddah         Jeddah Corniche Circuit
# 2      3      Australia  Melbourne    Melbourne Grand Prix Circuit
# 3      4     Azerbaijan       Baku               Baku City Circuit
# 4      5  United States      Miami   Miami International Autodrome
# 5      6          Italy      Imola   Autodromo Enzo e Dino Ferrari
# 6      7         Monaco     Monaco               Circuit de Monaco
# 7      8          Spain  Catalunya  Circuit de Barcelona-Catalunya
# 8      9         Canada   Montréal       Circuit Gilles-Villeneuve
# 9     10        Austria  Spielberg                   Red Bull Ring
#
#                                              GP Name   Race Date  First GP  \
# 0                                Gulf Air Bahrain GP  05/03/2023      2004
# 1                               STC Saudi Arabian GP  19/03/2023      2021
# ...

# %%
results_2024.head()
# Out:
#    Round       Country       City                    Circuit Name  \
# 0      1       Bahrain     Sakhir   Bahrain International Circuit
# 1      2  Saudi Arabia     Jeddah         Jeddah Corniche Circuit
# 2      3     Australia  Melbourne  Albert Park Grand Prix Circuit
# 3      4         Japan     Suzuka                  Suzuka Circuit
# 4      5         China   Shanghai  Shanghai International Circuit
#
#                    GP Name   Race Date  First GP  Number of Laps  \
# 0      Gulf Air Bahrain GP  02/03/2024      2004              57
# 1     STC Saudi Arabian GP  09/03/2024      2021              50
# 2      Rolex Australian GP  24/03/2024      1996              58
# 3  MSC Cruises Japanese GP  07/04/2024      1987              53
# 4        Lenovo Chinese GP  21/04/2024      2004              56
#
#    Circuit Length(km)  Race Distance(km) Lap Record        Record Owner  \
# 0               5.412            308.238   1:31.447    Pedro de la Rosa
# ...

# %% [markdown]
# just to be sure:

# %%
print(results_2020.columns == results_2021.columns)
print(results_2021.columns == results_2022.columns)
print(results_2022.columns == results_2023.columns)
print(results_2023.columns == results_2024.columns)
# Out:
# [ True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True]
# [ True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True]
# [ True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True]
# [ True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True]

# %% [markdown]
# ### changing date formatting

# %%
print(results_2020.iloc[0,5])
print(results_2021.iloc[0,5])
print(results_2022.iloc[0,5])
print(results_2023.iloc[0,5])
print(results_2024.iloc[0,5])
# Out:
# 5 Jul 2020
# 28 Mar 2021
# 20/03/2022
# 05/03/2023
# 02/03/2024

# %%
# 4NA7E1
def format_date(date):
    day, month, year = date.split()
    if len(day) == 1:
        day = "0" + day
    def switch_month(x):
        if x == "Jan":
            return "01"
        elif x == "Feb":
            return "02"
        elif x == "Mar":
            return "03"
        elif x == "Apr":
            return "04"
        elif x == "May":
            return "05"
        elif x == "Jun":
            return "06"
        elif x == "Jul":
            return "07"
        elif x == "Aug":
            return "08"
        elif x == "Sep":
            return "09"
        elif x == "Oct":
            return "10"
        elif x == "Nov":
            return "11"
        elif x == "Dec":
            return "12"
    month = switch_month(month)
    return day + "/" + month + "/" + year

# %%
format_date(results_2020.iloc[0,5])
# Out:
# '05/07/2020'

# %%
results_2020["Race Date"] = results_2020["Race Date"].apply(format_date)
results_2021["Race Date"] = results_2021["Race Date"].apply(format_date)

# %%
print(results_2020.iloc[0,5])
print(results_2021.iloc[0,5])
print(results_2022.iloc[0,5])
print(results_2023.iloc[0,5])
print(results_2024.iloc[0,5])
# Out:
# 05/07/2020
# 28/03/2021
# 20/03/2022
# 05/03/2023
# 02/03/2024

# %% [markdown]
# ### we will need to get Circuit IDs from Circuit dimension table

# %%
circ = pd.read_csv("circuts_scd2.csv")

# %%
circ[circ['Location'] == "Sakhir"] 
"Sakhir" in circ['Location'].values
# Out:
# True

# %%
for index, row in results_2020.iterrows():
    if row['Circuit Name'] in circ['Circuit'].values or :
        print(row['City'])
# Out:
# Spielberg
# Spielberg
# Budapest
# Silverstone
# Catalunya
# Spa-Francorchamps
# Sochi
# Istanbul
# Sakhir
# Yas Island

# %%
results_2020.head(15)
# Out:
#     Round        Country               City  \
# 0       1        Austria          Spielberg
# 1       2        Austria          Spielberg
# 2       3        Hungary           Budapest
# 3       4  Great Britain        Silverstone
# 4       5  Great Britain        Silverstone
# 5       6          Spain          Catalunya
# 6       7        Belgium  Spa-Francorchamps
# 7       8          Italy              Monza
# 8       9          Italy            Tuscany
# 9      10         Russia              Sochi
# 10     11        Germany            Nurburg
# 11     12       Portugal           Portimao
# 12     13          Italy              Imola
# 13     14         Turkey           Istanbul
# 14     15        Bahrain             Sakhir
#
#                           Circuit Name           GP Name   Race Date  \
# 0                        Red Bull Ring           Austria  05/07/2020
# 1                        Red Bull Ring            Styria  12/07/2020
# ...

# %%
circ[circ['Location'] == "Budapest"]
# Out:
# Empty DataFrame
# Columns: [Circuit, Type, Direction, Location, Country, Last length used, Turns, Grands Prix, Season(s), Latitude, Longitude, Grands Prix held, from, to, isActivePeriod, CircuitLocationID]
# Index: []

# %% [markdown]
# as there are a lot of problems with the extracted data e.g typos, we have to assign IDs manually

# %%
results_2020.head(20)
# Out:
#     Round        Country               City  \
# 0       1        Austria          Spielberg
# 1       2        Austria          Spielberg
# 2       3        Hungary           Budapest
# 3       4  Great Britain        Silverstone
# 4       5  Great Britain        Silverstone
# 5       6          Spain          Catalunya
# 6       7        Belgium  Spa-Francorchamps
# 7       8          Italy              Monza
# 8       9          Italy            Tuscany
# 9      10         Russia              Sochi
# 10     11        Germany            Nurburg
# 11     12       Portugal           Portimao
# 12     13          Italy              Imola
# 13     14         Turkey           Istanbul
# 14     15        Bahrain             Sakhir
# 15     16        Bahrain             Sakhir
# 16     17      Abu Dhabi         Yas Island
#
#                                    Circuit Name           GP Name   Race Date  \
# 0                                 Red Bull Ring           Austria  05/07/2020
# ...

# %%
ids = [23561,23561,59141,18634,18634,76541,40690,58117,94760,87735, 69792,68059,26224,59748,90672,90672,19921]
results_2020["CircuitLocationID"] = ids

# %%
results_2020.head(20)
# Out:
#     Round        Country               City  \
# 0       1        Austria          Spielberg
# 1       2        Austria          Spielberg
# 2       3        Hungary           Budapest
# 3       4  Great Britain        Silverstone
# 4       5  Great Britain        Silverstone
# 5       6          Spain          Catalunya
# 6       7        Belgium  Spa-Francorchamps
# 7       8          Italy              Monza
# 8       9          Italy            Tuscany
# 9      10         Russia              Sochi
# 10     11        Germany            Nurburg
# 11     12       Portugal           Portimao
# 12     13          Italy              Imola
# 13     14         Turkey           Istanbul
# 14     15        Bahrain             Sakhir
# 15     16        Bahrain             Sakhir
# 16     17      Abu Dhabi         Yas Island
#
#                                    Circuit Name           GP Name   Race Date  \
# 0                                 Red Bull Ring           Austria  05/07/2020
# ...

# %%
results_2021.head(25)
# Out:
#     Round        Country               City  \
# 0       1        Bahrain             Sakhir
# 1       2          Italy              Imola
# 2       3       Portugal           Portimao
# 3       4          Spain          Catalunya
# 4       5         Monaco        Monte Carlo
# 5       6     Azerbaijan               Baku
# 6       7         France       Le Castellet
# 7       8        Austria          Spielberg
# 8       9        Austria          Spielberg
# 9      10  Great Britain         Siverstone
# 10     11        Hungary           Budapest
# 11     12        Belgium  Spa-Francorchamps
# 12     13    Netherlands          Zandvoort
# 13     14          Italy              Monza
# 14     15         Russia              Sochi
# 15     16         Turkey           Istanbul
# 16     17  United States             Austin
# 17     18         Mexico        Mexico City
# 18     19         Brazil          Sao Paulo
# 19     20          Qatar             Losail
# ...

# %%
ids = [90672,26224, 68059,76541,87588,37306,74716,23561,23561,18634, 59141, 40690, 71385,58117,
      87735,59748, 31674,55162,80581,22293,58816,19921]
results_2021["CircuitLocationID"] = ids
results_2021.head()
# Out:
#    Round   Country         City                        Circuit Name  \
# 0      1   Bahrain       Sakhir       Bahrain International Circuit
# 1      2     Italy        Imola       Autodromo Enzo e Dino Ferrari
# 2      3  Portugal     Portimao  Autodromo Internacional do Algarve
# 3      4     Spain    Catalunya      Circuit de Barcelona-Catalunya
# 4      5    Monaco  Monte Carlo                   Circuit de Monaco
#
#           GP Name   Race Date  First GP  Number of Laps  Circuit Length(km)  \
# 0         Bahrain  28/03/2021      2004              57               5.412
# 1  Emilia Romagna  18/04/2021      1980              63               4.909
# 2        Portugal  02/05/2021      2020              66               4.653
# 3           Spain  09/05/2021      1991              66               4.675
# 4          Monaco  23/05/2021      1950              78               3.337
#
#    Race Distance(km) Lap Record      Record Owner  Record Year  Turns  \
# ...

# %%
results_2022.head(25)
# Out:
#     Round        Country               City  \
# 0       1        Bahrain             Sakhir
# 1       2   Saudi Arabia             Jeddah
# 2       3      Australia          Melbourne
# 3       4          Italy              Imola
# 4       5  United States              Miami
# 5       6          Spain          Catalunya
# 6       7         Monaco        Monte Carlo
# 7       8     Azerbaijan               Baku
# 8       9         Canada           Montréal
# 9      10  Great Britain        Silverstone
# 10     11        Austria          Spielberg
# 11     12         France       Le Castellet
# 12     13        Hungary           Budapest
# 13     14        Belgium  Spa-Francorchamps
# 14     15    Netherlands          Zandvoort
# 15     16          Italy              Monza
# 16     17      Singapore          Singapore
# 17     18          Japan             Suzuka
# 18     19  United States             Austin
# 19     20         Mexico        Mexico City
# ...

# %%
ids = [90672, 58816,73060, 26224, 78952,76541,87588, 37306, 75121,18634,23561,74716,59141,
      40690, 71385,58117, 89821, 60239, 31674, 55162,80581,19921]
results_2022["CircuitLocationID"] = ids
results_2022.head()
# Out:
#    Round        Country       City                   Circuit Name  \
# 0      1        Bahrain     Sakhir  Bahrain International Circuit
# 1      2   Saudi Arabia     Jeddah        Jeddah Corniche Circuit
# 2      3      Australia  Melbourne            Albert Park Circuit
# 3      4          Italy      Imola  Autodromo Enzo e Dino Ferrari
# 4      5  United States      Miami  Miami International Autodrome
#
#                                              GP Name   Race Date  First GP  \
# 0                                Gulf Air Bahrain GP  20/03/2022      2004
# 1                               STC Saudi Arabian GP  27/03/2022      2021
# 2                             Heineken Australian GP  10/04/2022      1996
# 3  Rolex Gran Premio Del Made in Italy e Dell'Emi...  24/04/2022      1980
# 4                                Crypto.com Miami GP  08/05/2022      2022
#
#    Number of Laps  Circuit Length(km)  Race Distance(km) Lap Record  \
# ...

# %%
results_2023.head(25)
# Out:
#     Round        Country               City  \
# 0       1        Bahrain             Sakhir
# 1       2   Saudi Arabia             Jeddah
# 2       3      Australia          Melbourne
# 3       4     Azerbaijan               Baku
# 4       5  United States              Miami
# 5       6          Italy              Imola
# 6       7         Monaco             Monaco
# 7       8          Spain          Catalunya
# 8       9         Canada           Montréal
# 9      10        Austria          Spielberg
# 10     11  Great Britain        Silverstone
# 11     12        Hungary           Budapest
# 12     13        Belgium  Spa-Francorchamps
# 13     14    Netherlands          Zandvoort
# 14     15          Italy              Monza
# 15     16      Singapore          Singapore
# 16     17          Japan             Suzuka
# 17     18          Qatar             Lusail
# 18     19  United States             Austin
# 19     20         Mexico        Mexico City
# ...

# %%
ids = [90672, 58816, 73060,37306, 78952, 26224, 87588,76541,75121, 23561, 18634, 
      59141, 40690, 71385,58117, 89821, 60239, 22293, 31674, 55162, 80581, 77635, 19921]
results_2023["CircuitLocationID"] = ids
results_2023.head()
# Out:
#    Round        Country       City                   Circuit Name  \
# 0      1        Bahrain     Sakhir  Bahrain International Circuit
# 1      2   Saudi Arabia     Jeddah        Jeddah Corniche Circuit
# 2      3      Australia  Melbourne   Melbourne Grand Prix Circuit
# 3      4     Azerbaijan       Baku              Baku City Circuit
# 4      5  United States      Miami  Miami International Autodrome
#
#                 GP Name   Race Date  First GP  Number of Laps  \
# 0   Gulf Air Bahrain GP  05/03/2023      2004              57
# 1  STC Saudi Arabian GP  19/03/2023      2021              50
# 2   Rolex Australian GP  02/04/2023      1996              58
# 3         Azerbaijan GP  30/04/2023      2016              51
# 4   Crypto.com Miami GP  07/05/2023      2022              57
#
#    Circuit Length(km)  Race Distance(km) Lap Record      Record Owner  \
# 0               5.412            308.238   1:31.447  Pedro de la Rosa
# ...

# %%
results_2024.head(25)
# Out:
#     Round               Country               City  \
# 0       1               Bahrain             Sakhir
# 1       2          Saudi Arabia             Jeddah
# 2       3             Australia          Melbourne
# 3       4                 Japan             Suzuka
# 4       5                 China           Shanghai
# 5       6         United States              Miami
# 6       7                 Italy              Imola
# 7       8                Monaco             Monaco
# 8       9                Canada           Montréal
# 9      10                 Spain          Barcelona
# 10     11               Austria          Spielberg
# 11     12         Great Britain        Silverstone
# 12     13               Hungary           Budapest
# 13     14               Belgium  Spa-Francorchamps
# 14     15           Netherlands          Zandvoort
# 15     16                 Italy              Monza
# 16     17            Azerbaijan               Baku
# ...

# %%
ids = [90672,58816,73060, 60239, 47869, 78952,26224, 87588,75121, 76541, 23561, 18634, 
      59141, 40690, 71385, 58117, 37306, 89821, 31674, 55162, 80581, 77635, 22293, 19921]
results_2024["CircuitLocationID"] = ids
results_2024.head()
# Out:
#    Round       Country       City                    Circuit Name  \
# 0      1       Bahrain     Sakhir   Bahrain International Circuit
# 1      2  Saudi Arabia     Jeddah         Jeddah Corniche Circuit
# 2      3     Australia  Melbourne  Albert Park Grand Prix Circuit
# 3      4         Japan     Suzuka                  Suzuka Circuit
# 4      5         China   Shanghai  Shanghai International Circuit
#
#                    GP Name   Race Date  First GP  Number of Laps  \
# 0      Gulf Air Bahrain GP  02/03/2024      2004              57
# 1     STC Saudi Arabian GP  09/03/2024      2021              50
# 2      Rolex Australian GP  24/03/2024      1996              58
# 3  MSC Cruises Japanese GP  07/04/2024      1987              53
# 4        Lenovo Chinese GP  21/04/2024      2004              56
#
#    Circuit Length(km)  Race Distance(km) Lap Record        Record Owner  \
# 0               5.412            308.238   1:31.447    Pedro de la Rosa
# ...

# %%
results_2024
# Out:
#     Round               Country               City  \
# 0       1               Bahrain             Sakhir
# 1       2          Saudi Arabia             Jeddah
# 2       3             Australia          Melbourne
# 3       4                 Japan             Suzuka
# 4       5                 China           Shanghai
# 5       6         United States              Miami
# 6       7                 Italy              Imola
# 7       8                Monaco             Monaco
# 8       9                Canada           Montréal
# 9      10                 Spain          Barcelona
# 10     11               Austria          Spielberg
# 11     12         Great Britain        Silverstone
# 12     13               Hungary           Budapest
# 13     14               Belgium  Spa-Francorchamps
# 14     15           Netherlands          Zandvoort
# 15     16                 Italy              Monza
# 16     17            Azerbaijan               Baku
# ...

# %%
dfs = [results_2020,results_2021,results_2022,results_2023,results_2024]
merged = pd.concat(dfs, ignore_index=True)

# %%
len(merged)
# Out:
# 108

# %%
merged.head(25)
# Out:
#     Round        Country               City  \
# 0       1        Austria          Spielberg
# 1       2        Austria          Spielberg
# 2       3        Hungary           Budapest
# 3       4  Great Britain        Silverstone
# 4       5  Great Britain        Silverstone
# 5       6          Spain          Catalunya
# 6       7        Belgium  Spa-Francorchamps
# 7       8          Italy              Monza
# 8       9          Italy            Tuscany
# 9      10         Russia              Sochi
# 10     11        Germany            Nurburg
# 11     12       Portugal           Portimao
# 12     13          Italy              Imola
# 13     14         Turkey           Istanbul
# 14     15        Bahrain             Sakhir
# 15     16        Bahrain             Sakhir
# 16     17      Abu Dhabi         Yas Island
# 17      1        Bahrain             Sakhir
# 18      2          Italy              Imola
# 19      3       Portugal           Portimao
# ...

# %%
for index, row in merged.iterrows():
    year = row["Race Date"][-4:]
    print(year)
# Out:
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2022
# 2022
# 2022
# 2022
# 2022
# 2022
# 2022
# 2022
# 2022
# 2022
# 2022
# 2022
# 2022
# 2022
# 2022
# 2022
# 2022
# 2022
# 2022
# 2022
# 2022
# 2022
# 2023
# 2023
# 2023
# 2023
# 2023
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [127], in <cell line: 1>()
#       1 for index, row in merged.iterrows():
# ----> 2     year = row["Race Date"][-4:]
#       3     print(year)
#
# TypeError: 'float' object is not subscriptable

# %%
results_2023.head(25)
# Out:
#     Round        Country               City  \
# 0       1        Bahrain             Sakhir
# 1       2   Saudi Arabia             Jeddah
# 2       3      Australia          Melbourne
# 3       4     Azerbaijan               Baku
# 4       5  United States              Miami
# 5       6          Italy              Imola
# 6       7         Monaco             Monaco
# 7       8          Spain          Catalunya
# 8       9         Canada           Montréal
# 9      10        Austria          Spielberg
# 10     11  Great Britain        Silverstone
# 11     12        Hungary           Budapest
# 12     13        Belgium  Spa-Francorchamps
# 13     14    Netherlands          Zandvoort
# 14     15          Italy              Monza
# 15     16      Singapore          Singapore
# 16     17          Japan             Suzuka
# 17     18          Qatar             Lusail
# 18     19  United States             Austin
# 19     20         Mexico        Mexico City
# ...

# %% [markdown]
# 5th row is imola race which was cancelled beacause of strong floods

# %%
merged.dropna(inplace = True)

# %%
len(merged)
# Out:
# 107

# %% [markdown]
# let's continue

# %%
for index, row in merged.iterrows():
    year = row["Race Date"][-4:]
    print(year)
# Out:
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2022
# 2022
# 2022
# 2022
# 2022
# 2022
# 2022
# 2022
# 2022
# 2022
# 2022
# 2022
# 2022
# 2022
# 2022
# 2022
# 2022
# 2022
# 2022
# 2022
# 2022
# 2022
# 2023
# 2023
# 2023
# 2023
# 2023
# 2023
# 2023
# 2023
# 2023
# 2023
# 2023
# 2023
# 2023
# 2023
# 2023
# 2023
# 2023
# 2023
# 2023
# 2023
# 2023
# 2023
# 2024
# 2024
# 2024
# 2024
# 2024
# 2024
# 2024
# 2024
# 2024
# 2024
# 2024
# 2024
# 2024
# 2024
# 2024
# 2024
# 2024
# 2024
# 2024
# 2024
# 2024
# 2024
# 2024
# 2024

# %%
indexes = []
for index, row in merged.iterrows():
    year = int(row["Race Date"][-4:])
    help = circ[circ["CircuitLocationID"] == row["CircuitLocationID"]]
    # print(len(help[(help["from"] <= year) & (help["to"] >= year)]))
    id = help.loc[(help["from"] <= year) & (help["to"] >= year), 'SKID']
    # merged["CircuitLocationID"] = id.values[0]
    indexes.append(id.values[0])
    # print(id.values[0]) #+ "     " + row["City"])
    # print(row["City"])
    # print("")

# %%
indexes
# Out:
# [174,
#  174,
#  131,
#  202,
#  202,
#  54,
#  74,
#  26,
#  17,
#  203,
#  167,
#  9,
#  19,
#  135,
#  34,
#  34,
#  210,
#  34,
#  19,
#  9,
#  54,
#  57,
#  36,
#  96,
#  174,
#  174,
#  202,
#  131,
#  74,
#  101,
#  26,
#  203,
#  135,
#  87,
#  14,
#  24,
#  143,
#  136,
#  210,
#  34,
#  136,
#  8,
#  19,
#  147,
#  54,
#  57,
#  36,
#  83,
#  202,
#  174,
#  96,
#  131,
#  74,
#  101,
#  26,
#  146,
#  206,
#  87,
#  14,
#  24,
#  210,
#  34,
#  136,
#  8,
#  36,
#  147,
#  57,
#  54,
#  83,
#  174,
#  202,
#  131,
#  74,
#  101,
#  26,
#  146,
#  206,
#  144,
#  87,
#  14,
#  24,
#  141,
#  210,
#  34,
#  136,
#  8,
#  206,
#  185,
#  147,
#  20,
#  57,
#  83,
#  54,
#  174,
#  202,
#  131,
#  74,
#  101,
#  26,
#  36,
#  146,
#  87,
#  14,
#  24,
#  141,
#  144,
#  210]

# %%
merged["CircuitLocationID"] = indexes

# %%
merged.head()
# Out:
#    Round        Country         City         Circuit Name           GP Name  \
# 0      1        Austria    Spielberg        Red Bull Ring           Austria
# 1      2        Austria    Spielberg        Red Bull Ring            Styria
# 2      3        Hungary     Budapest          Hungaroring           Hungary
# 3      4  Great Britain  Silverstone  Silverstone Circuit     Great Britain
# 4      5  Great Britain  Silverstone  Sliverstone Circuit  70th Anniversary
#
#     Race Date  First GP  Number of Laps  Circuit Length(km)  \
# 0  05/07/2020      1970              71               4.318
# 1  12/07/2020      1970              71               4.318
# 2  19/07/2020      1986              70               4.381
# 3  02/08/2020      1950              52               5.891
# 4  09/08/2020      1950              52               5.891
#
#    Race Distance(km) Lap Record    Record Owner  Record Year  Turns  \
# 0            306.452   1:05.619    Carlos Sainz         2020     10
# ...

# %%
merged.to_csv("fect_weather.csv", index=False)

# %% [markdown]
# ## adding weather data through openmeteo api

# %%
# !pip install openmeteo-requests
# !pip install requests-cache retry-requests
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 668.4/668.4 kB 3.2 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 635.6/635.6 kB 3.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 4.1 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7/7 [openmeteo-requests]iquests]uture]
# ...
#
# [notice] A new release of pip is available: 25.1 -> 25.1.1
# [notice] To update, run: pip install --upgrade pip
# ...
#   Attempting uninstall: attrs
#     Found existing installation: attrs 23.2.0
#     Uninstalling attrs-23.2.0:
#       Successfully uninstalled attrs-23.2.0
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5/5 [requests-cache]m [requests-cache]
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# spyder 5.1.5 requires pyqt5<5.13, which is not installed.
# ...

# %%
import openmeteo_requests
import requests_cache
from retry_requests import retry

def extract_weather_data(date, lat, long):
    # Setup the Open-Meteo API client with cache and retry on error
    cache_session = requests_cache.CachedSession('.cache', expire_after = -1)
    retry_session = retry(cache_session, retries = 5, backoff_factor = 0.2)
    openmeteo = openmeteo_requests.Client(session = retry_session)
    
    # Make sure all required weather variables are listed here
    # The order of variables in hourly or daily is important to assign them correctly below
    url = "https://archive-api.open-meteo.com/v1/archive"
    params = {
    	"latitude": lat,
    	"longitude": long,
    	"start_date": date,
    	"end_date": date,
    	"daily": ["temperature_2m_mean", "wind_speed_10m_max", "rain_sum", "relative_humidity_2m_mean"],
    	"timezone": "GMT"
    }
    responses = openmeteo.weather_api(url, params=params)
    
    # Process first location. Add a for-loop for multiple locations or weather models
    response = responses[0]
    # print(f"Coordinates {response.Latitude()}°N {response.Longitude()}°E")
    # print(f"Elevation {response.Elevation()} m asl")
    # print(f"Timezone {response.Timezone()}{response.TimezoneAbbreviation()}")
    # print(f"Timezone difference to GMT+0 {response.UtcOffsetSeconds()} s")
    
    # Process daily data. The order of variables needs to be the same as requested.
    daily = response.Daily()
    daily_temperature_2m_mean = daily.Variables(0).ValuesAsNumpy()
    daily_wind_speed_10m_max = daily.Variables(1).ValuesAsNumpy()
    daily_rain_sum = daily.Variables(2).ValuesAsNumpy()
    daily_relative_humidity_2m_mean = daily.Variables(3).ValuesAsNumpy()
    
    daily_data = {"date": pd.date_range(
    	start = pd.to_datetime(daily.Time(), unit = "s", utc = True),
    	end = pd.to_datetime(daily.TimeEnd(), unit = "s", utc = True),
    	freq = pd.Timedelta(seconds = daily.Interval()),
    	inclusive = "left"
    )}
    
    daily_data["temperature_2m_mean"] = daily_temperature_2m_mean
    daily_data["wind_speed_10m_max"] = daily_wind_speed_10m_max
    daily_data["rain_sum"] = daily_rain_sum
    daily_data["relative_humidity_2m_mean"] = daily_relative_humidity_2m_mean
    
    daily_dataframe = pd.DataFrame(data = daily_data)
    return daily_dataframe.iloc[0,1],daily_dataframe.iloc[0,2],daily_dataframe.iloc[0,3],daily_dataframe.iloc[0,4]

# %%
from datetime import datetime
def convert_date_format(date_str):
    return datetime.strptime(date_str, "%d/%m/%Y").strftime("%Y-%m-%d")

# %%
merged['Race Date'] = merged['Race Date'].apply(convert_date_format)

# %%
merged2 = merged[['Race Date', 'CircuitLocationID', 'Round']]

# %%
merged2.head()
# Out:
#     Race Date  CircuitLocationID  Round
# 0  2020-07-05                174      1
# 1  2020-07-12                174      2
# 2  2020-07-19                131      3
# 3  2020-08-02                202      4
# 4  2020-08-09                202      5

# %%
extract_weather_data("2020-08-09",52.0711,-1.0161)
# Out:
# (20.520412, 22.691423, 0.0, 74.793526)

# %% [markdown]
# ### we need a join to get coords for our for function

# %%
circ.head()
# Out:
#                         Circuit            Type  Direction    Location  \
# 0       Adelaide Street Circuit  Street circuit  Clockwise    Adelaide
# 1              Ain-Diab Circuit    Road circuit  Clockwise  Casablanca
# 2  Aintree Motor Racing Circuit    Road circuit  Clockwise     Aintree
# 3  Aintree Motor Racing Circuit    Road circuit  Clockwise     Aintree
# 4  Aintree Motor Racing Circuit    Road circuit  Clockwise     Aintree
#
#           Country     Last length used Turns  Latitude  Longitude  \
# 0       Australia  3.780 km (2.349 mi)    16  -34.9306   138.6206
# 1         Morocco  7.618 km (4.734 mi)    18   33.5786    -7.6875
# 2  United Kingdom  4.828 km (3.000 mi)    12   53.4769    -2.9406
# 3  United Kingdom  4.828 km (3.000 mi)    12   53.4769    -2.9406
# 4  United Kingdom  4.828 km (3.000 mi)    12   53.4769    -2.9406
#
#    Grands Prix held  from    to  isActivePeriod  CircuitLocationID  SKID
# ...

# %%
merged_with_coords = pd.merge(merged2, circ, left_on='CircuitLocationID', right_on='SKID', how='inner')

# %%
merged_with_coords.head()
# Out:
#     Race Date  CircuitLocationID_x  Round              Circuit          Type  \
# 0  2020-07-05                  174      1        Red Bull Ring  Race circuit
# 1  2020-07-12                  174      2        Red Bull Ring  Race circuit
# 2  2020-07-19                  131      3          Hungaroring  Race circuit
# 3  2020-08-02                  202      4  Silverstone Circuit  Race circuit
# 4  2020-08-09                  202      5  Silverstone Circuit  Race circuit
#
#    Direction     Location         Country     Last length used Turns  \
# 0  Clockwise    Spielberg         Austria  4.318 km (2.683 mi)    10
# 1  Clockwise    Spielberg         Austria  4.318 km (2.683 mi)    10
# 2  Clockwise     Mogyoród         Hungary  4.381 km (2.722 mi)    14
# 3  Clockwise  Silverstone  United Kingdom  5.891 km (3.660 mi)    18
# 4  Clockwise  Silverstone  United Kingdom  5.891 km (3.660 mi)    18
#
#    Latitude  Longitude  Grands Prix held  from    to  isActivePeriod  \
# ...

# %%
merged.head()
# Out:
#    Round        Country         City         Circuit Name           GP Name  \
# 0      1        Austria    Spielberg        Red Bull Ring           Austria
# 1      2        Austria    Spielberg        Red Bull Ring            Styria
# 2      3        Hungary     Budapest          Hungaroring           Hungary
# 3      4  Great Britain  Silverstone  Silverstone Circuit     Great Britain
# 4      5  Great Britain  Silverstone  Sliverstone Circuit  70th Anniversary
#
#     Race Date  First GP  Number of Laps  Circuit Length(km)  \
# 0  2020-07-05      1970              71               4.318
# 1  2020-07-12      1970              71               4.318
# 2  2020-07-19      1986              70               4.381
# 3  2020-08-02      1950              52               5.891
# 4  2020-08-09      1950              52               5.891
#
#    Race Distance(km) Lap Record    Record Owner  Record Year  Turns  \
# 0            306.452   1:05.619    Carlos Sainz         2020     10
# ...

# %%
merged_with_coords = merged_with_coords[['Race Date','CircuitLocationID_x','Round','Latitude','Longitude']]
len(merged_with_coords)
# Out:
# 107

# %%
merged_with_coords[['temperature', 'wind', 'rain','humidity']] = merged_with_coords.apply(
    lambda row: pd.Series(extract_weather_data(row['Race Date'], row['Latitude'], row['Longitude'])),
    axis=1
)

# %%
merged_with_coords.head()
# Out:
#     Race Date  CircuitLocationID_x  Round  Latitude  Longitude  temperature  \
# 0  2020-07-05                  174      1   47.2197    14.7647    19.602833
# 1  2020-07-12                  174      2   47.2197    14.7647    14.469502
# 2  2020-07-19                  131      3   47.5822    19.2511    17.116833
# 3  2020-08-02                  202      4   52.0711    -1.0161    16.551664
# 4  2020-08-09                  202      5   52.0711    -1.0161    20.520412
#
#         wind      rain   humidity
# 0   8.905908  0.000000  68.644875
# 1  11.525623  0.000000  67.618340
# 2  15.790833  6.599999  87.799622
# 3  18.003599  0.100000  60.793613
# 4  22.691423  0.000000  74.793526

# %%
merged_with_coords.iloc[41,:]
# Out:
# Race Date              2022-04-10
# CircuitLocationID_x             8
# Round                           3
# Latitude                 -37.8497
# Longitude                144.9683
# temperature             20.716333
# wind                    27.691935
# rain                          1.5
# humidity                66.026161
# Name: 41, dtype: object

# %%
weather_cols = ['temperature', 'wind', 'rain', 'humidity']
merged_with_coords[weather_cols] = merged_with_coords[weather_cols].round(1)
merged_with_coords.head()
# Out:
#     Race Date  CircuitLocationID_x  Round  Latitude  Longitude  temperature  \
# 0  2020-07-05                  174      1   47.2197    14.7647         19.6
# 1  2020-07-12                  174      2   47.2197    14.7647         14.5
# 2  2020-07-19                  131      3   47.5822    19.2511         17.1
# 3  2020-08-02                  202      4   52.0711    -1.0161         16.6
# 4  2020-08-09                  202      5   52.0711    -1.0161         20.5
#
#         wind  rain   humidity
# 0   8.900000   0.0  68.599998
# 1  11.500000   0.0  67.599998
# 2  15.800000   6.6  87.800003
# 3  18.000000   0.1  60.799999
# 4  22.700001   0.0  74.800003

# %%
merged_with_coords[weather_cols] = merged_with_coords[weather_cols].round(1).astype(float)

# %%
from datetime import datetime

def convert_to_style_112(date_input):
    if isinstance(date_input, str):
        date_obj = datetime.strptime(date_input, "%Y-%m-%d")
    else:
        date_obj = date_input
    return int(date_obj.strftime("%Y%m%d"))

# %%
convert_to_style_112("2023-12-09")
# Out:
# 20231209

# %%
merged_with_coords['Race Date'] = merged_with_coords['Race Date'].apply(convert_to_style_112)

# %%
merged_with_coords.head()
# Out:
#    Race Date  CircuitLocationID_x  Round  Latitude  Longitude  temperature  \
# 0   20200705                  174      1   47.2197    14.7647         19.6
# 1   20200712                  174      2   47.2197    14.7647         14.5
# 2   20200719                  131      3   47.5822    19.2511         17.1
# 3   20200802                  202      4   52.0711    -1.0161         16.6
# 4   20200809                  202      5   52.0711    -1.0161         20.5
#
#    wind  rain  humidity
# 0   8.9   0.0      68.6
# 1  11.5   0.0      67.6
# 2  15.8   6.6      87.8
# 3  18.0   0.1      60.8
# 4  22.7   0.0      74.8

# %%
merged_with_coords.to_csv("fect_weather.csv", index=False)
